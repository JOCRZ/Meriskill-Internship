# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('HR.csv')

# %%
df = data.copy(deep=True)

# %%
columns_to_drop = ['Employee counts']

# %% [markdown]
# no Na values, no Null values , no duplicates

# %%
df.Education.unique()
# Out:
# array([2, 1, 4, 3, 5])

# %% [markdown]
# -  typically represents the level of education of individuals
#
# Education Level 1: This is likely the lowest education level. In many datasets, it could correspond to individuals who have completed high school or have an equivalent education.
#
# Education Level 2: This is generally a higher education level than 1 but lower than 3. It might represent individuals with some college education or an associate's degree.
#
# Education Level 3: A level higher than 2 but lower than 4. In many cases, this could represent individuals with a bachelor's degree.
#
# Education Level 4: This is often associated with individuals who have completed graduate-level education. It might represent individuals with a master's degree.
#
# Education Level 5: This is typically the highest education level in the dataset. It might represent individuals with a doctorate (Ph.D.) or other advanced degrees.

# %%
df.JobInvolvement.unique()
# Out:
# array([3, 2, 4, 1])

# %% [markdown]
# - typically represents the level of job involvement or engagement of individuals in their work.
#
# Job Involvement Level 1: This typically represents low job involvement or engagement. Individuals with a value of 1 may be less committed or engaged in their work, and they may show minimal interest in their job responsibilities.
#
# Job Involvement Level 2: This represents a moderate level of job involvement. Individuals with a value of 2 may have a moderate level of commitment and engagement in their work. They may be somewhat interested in their job responsibilities.
#
# Job Involvement Level 3: This typically represents a relatively high level of job involvement. Individuals with a value of 3 are likely to be more committed and engaged in their work. They may show a significant level of interest and dedication to their job.
#
# Job Involvement Level 4: This often indicates a very high level of job involvement or engagement. Individuals with a value of 4 may be highly committed and engaged in their work. They are likely to be very interested in their job responsibilities and may go above and beyond in their roles.

# %%
df.JobLevel.unique()
# Out:
# array([2, 1, 3, 4, 5])

# %% [markdown]
# - typically represents the hierarchical or seniority levels of job positions within an organization.
#
# Job Level 1: This is often associated with entry-level or junior positions within an organization. Individuals at this level typically have the least seniority and may perform basic tasks or roles.
#
# Job Level 2: Individuals at this level are generally considered to be in mid-level positions. They may have more responsibilities and experience than those at Job Level 1 but are not yet in senior or leadership roles.
#
# Job Level 3: Job Level 3 typically represents positions with higher responsibilities and possibly some degree of leadership or management duties. Individuals at this level may be considered middle managers or supervisors.
#
# Job Level 4: Individuals at this level often hold senior management or leadership positions within an organization. They may have significant decision-making authority and oversee multiple teams or departments.
#
# Job Level 5: This is often associated with the highest-ranking positions within an organization, such as executive or C-suite roles. Individuals at this level hold the most senior and influential positions, often responsible for setting the strategic direction of the company.

# %%
df.JobSatisfaction.unique()
# Out:
# array([4, 2, 3, 1])

# %% [markdown]
# - typically represents the level of job satisfaction
#
# Job Satisfaction Level 1: This usually represents low job satisfaction. Individuals with a value of 1 may be dissatisfied or very unhappy with their current job. They may experience significant job-related challenges or find their work environment unsatisfactory.
#
# Job Satisfaction Level 2: This is often associated with moderate job satisfaction. Individuals with a value of 2 may have mixed feelings about their job. They may find some aspects of their work fulfilling while also experiencing some dissatisfaction or room for improvement.
#
# Job Satisfaction Level 3: Job Satisfaction Level 3 typically represents a relatively high level of job satisfaction. Individuals with a value of 3 are likely to be content and satisfied with their current job. They may find their work meaningful and fulfilling.
#
# Job Satisfaction Level 4: This often indicates very high job satisfaction. Individuals with a value of 4 are likely to be extremely satisfied and happy with their current job. They may consider their work environment and job roles highly fulfilling and rewarding.

# %%
df.NumCompaniesWorked.unique()
# Out:
# array([8, 1, 6, 9, 0, 4, 5, 2, 7, 3])

# %%
df.StockOptionLevel.unique()
# Out:
# array([0, 1, 3, 2])

# %% [markdown]
# - The "Stock Option Level" column, with unique values of 0, 1, 2, and 3, typically represents the level or availability of stock options provided to employees as part of their compensation package. Here's a general interpretation of these unique values:
#
# Stock Option Level 0: This often represents that employees do not have any stock options as part of their compensation package. They are not granted or eligible for stock options.
#
# Stock Option Level 1: Individuals with a value of 1 may have access to a basic or lower level of stock options. This might include a limited number of stock options or options with certain restrictions.
#
# Stock Option Level 2: A value of 2 often indicates a higher or more generous level of stock options. Employees with this level may have more stock options available to them, potentially with fewer restrictions or more favorable terms.
#
# Stock Option Level 3: This typically represents the highest level of stock options provided to employees. Individuals with a value of 3 may have a significant number of stock options with attractive terms and conditions.

# %%
df.RelationshipSatisfaction.unique()
# Out:
# array([1, 4, 2, 3])

# %% [markdown]
# - The "Relationship Satisfaction" column, with unique values of 1, 2, 3, and 4, typically represents the level of satisfaction individuals have with their personal relationships, which may include relationships outside of the workplace. Here is a general interpretation of these unique values:
#
# Relationship Satisfaction Level 1: This usually represents low relationship satisfaction. Individuals with a value of 1 may be dissatisfied or very unhappy with their personal relationships. They may experience significant challenges or dissatisfaction in their relationships.
#
# Relationship Satisfaction Level 2: This is often associated with moderate relationship satisfaction. Individuals with a value of 2 may have mixed feelings about their personal relationships. They may find some aspects of their relationships fulfilling while also experiencing some dissatisfaction or room for improvement.
#
# Relationship Satisfaction Level 3: Relationship Satisfaction Level 3 typically represents a relatively high level of satisfaction with personal relationships. Individuals with a value of 3 are likely to be content and satisfied with their relationships. They may find their personal relationships meaningful and fulfilling.
#
# Relationship Satisfaction Level 4: This often indicates very high relationship satisfaction. Individuals with a value of 4 are likely to be extremely satisfied and happy with their personal relationships. They may consider their relationships to be highly fulfilling and rewarding.

# %%
df.Department.unique()
# Out:
# array(['Sales', 'Research & Development', 'Human Resources'], dtype=object)

# %%
df.EducationField.unique()
# Out:
# array(['Life Sciences', 'Other', 'Medical', 'Marketing',
#        'Technical Degree', 'Human Resources'], dtype=object)

# %%
pd.set_option('display.max_columns', None)

# %%
# numerical columns
num_col = df[['Age','DailyRate','EmployeeNumber','MonthlyIncome','MonthlyRate']]

# %%
# categorical columns
cat_col = df[['Attrition','BusinessTravel','Department','EducationField','Gender','JobRole','MaritalStatus','OverTime']]

# %%
# Num category
ncat_col = df[['Education','EnvironmentSatisfaction','JobInvolvement','JobLevel','JobSatisfaction','RelationshipSatisfaction','StockOptionLevel','WorkLifeBalance']]

# %%
# num long categories
nlcat_col = df[['DistanceFromHome','HourlyRate','NumCompaniesWorked','PercentSalaryHike','TotalWorkingYears','TrainingTimesLastYear','YearsAtCompany','YearsInCurrentRole','YearsSinceLastPromotion','YearsWithCurrManager']]

# %%
df.BusinessTravel.unique()
# Out:
# array(['Travel_Rarely', 'Travel_Frequently', 'Non-Travel'], dtype=object)

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
"""
# doubt to drop
PerformanceRating

# to drop
EmployeeCount Over18 StandardHours

"""
# Out:
# '\n# doubt to drop\nPerformanceRating\n\n# to drop\nEmployeeCount Over18 StandardHours\n\n'

# %%
df.head(3)
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# 0                        2  Female          94               3         2
# 1                        3    Male          61               2         2
# 2                        4    Male          92               2         1
#
#                  JobRole  JobSatisfaction MaritalStatus  MonthlyIncome  \
# ...

# %%
df.describe().columns
# Out:
# Index(['Age', 'DailyRate', 'DistanceFromHome', 'Education', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobSatisfaction', 'MonthlyIncome',
#        'MonthlyRate', 'NumCompaniesWorked', 'PercentSalaryHike',
#        'PerformanceRating', 'RelationshipSatisfaction', 'StandardHours',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %%
cormap = df[['Age', 'DailyRate', 'DistanceFromHome','Education',
       'EmployeeNumber', 'EnvironmentSatisfaction', 'HourlyRate',
       'JobInvolvement', 'JobLevel', 'JobSatisfaction', 'MonthlyIncome',
       'MonthlyRate', 'NumCompaniesWorked', 'PercentSalaryHike',
       'PerformanceRating', 'RelationshipSatisfaction', 
       'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
       'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
       'YearsSinceLastPromotion', 'YearsWithCurrManager']].corr()
cormap.style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_0859a_row0_col0, #T_0859a_row1_col1, #T_0859a_row2_col2, #T_0859a_row3_col3, #T_0859a_row4_col4, #T_0859a_row5_col5, #T_0859a_row6_col6, #T_0859a_row7_col7, #T_0859a_row8_col8, #T_0859a_row9_col9, #T_0859a_row10_col10, #T_0859a_row11_col11, #T_0859a_row12_col12, #T_0859a_row13_col13, #T_0859a_row14_col14, #T_0859a_row15_col15, #T_0859a_row16_col16, #T_0859a_row17_col17, #T_0859a_row18_col18, #T_0859a_row19_col19, #T_0859a_row20_col20, #T_0859a_row21_col21, #T_0859a_row22_col22, #T_0859a_row23_col23 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# ...

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(data = cormap, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Map of Numerical Columns')
plt.show()

# %% [markdown]
# job level and monthly income
# job level total working years

# %%
df2 = df.copy(deep=True)

# %%
df2.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
df2.Education.unique()
# Out:
# array([2, 1, 4, 3, 5])

# %% [markdown]
# df2['Attrition'] = np.where(df2['Attrition'] == 'Yes', 1, 0)

# %%
mapping = {
    1 : "High School",
    2 : "Higher Secondary",
    3 : "Bacherlors",
    4 : "Masters",
    5 : "Doctorate"
}

df2["Education"] = df2["Education"].map(mapping)

# %% [markdown]
# mapping = {
#     1 : "Junior",
#     2 : "Senior",
#     3 : "Manager",
#     4 : "Senior Manager",
#     5 : "Executive"
# }
#
# df2["JobLevel"] = df2["JobLevel"].map(mapping)

# %%
df2 = df2.drop(columns=['EmployeeCount','Over18'],axis=1)

# %%
df2.sample(5)
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 458    40        No         Non-Travel       1094                   Sales
# 1314   45        No         Non-Travel        589                   Sales
# 910    23        No      Travel_Rarely        373  Research & Development
# 439    31       Yes  Travel_Frequently        534  Research & Development
# 583    34        No      Travel_Rarely       1111                   Sales
#
#       DistanceFromHome         Education EducationField  EmployeeNumber  \
# 458                 28        Bacherlors          Other             615
# 1314                 2           Masters  Life Sciences            1845
# 910                  1  Higher Secondary  Life Sciences            1270
# 439                 20        Bacherlors  Life Sciences             587
# 583                  8  Higher Secondary  Life Sciences             808
#
#       EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# ...

# %%
df2[['Age','DailyRate','EmployeeNumber','MonthlyIncome','MonthlyRate']].hist()
# Out:
# array([[<Axes: title={'center': 'Age'}>,
#         <Axes: title={'center': 'DailyRate'}>],
#        [<Axes: title={'center': 'EmployeeNumber'}>,
#         <Axes: title={'center': 'MonthlyIncome'}>],
#        [<Axes: title={'center': 'MonthlyRate'}>, <Axes: >]], dtype=object)

# %% [markdown]
# With the columns you provided, which seem to be related to employee data, you can generate various insights and perform different types of analysis. Here are some insights and analyses you can generate using this dataset:
#
# 1. **Descriptive Statistics:**
#    - Calculate summary statistics for numeric columns (e.g., mean, median, standard deviation, min, max).
#    - Count the number of unique values in categorical columns.
#
# 2. **Attrition Analysis:**
#    - Calculate the attrition rate within the organization.
#    - Examine the distribution of 'Attrition' with respect to other variables to identify factors associated with attrition.
#
# 3. **Employee Demographics:**
#    - Analyze the distribution of 'Gender,' 'MaritalStatus,' 'Education,' and 'Age' to understand the demographics of the workforce.
#
# 4. **Employee Satisfaction:**
#    - Analyze the distribution of 'JobSatisfaction,' 'EnvironmentSatisfaction,' 'RelationshipSatisfaction,' and 'WorkLifeBalance' to assess employee satisfaction levels.
#
# 5. **Salary and Compensation:**
#    - Investigate 'MonthlyIncome,' 'HourlyRate,' and 'TotalWorkingYears' to understand salary and compensation trends.
#    - Analyze the impact of 'PercentSalaryHike' on job satisfaction and attrition.
#
# 6. **Career Progression:**
#    - Examine 'JobLevel' and 'YearsAtCompany' to understand career progression within the organization.
#    - Analyze 'YearsInCurrentRole' and 'YearsSinceLastPromotion' to assess promotion patterns.
#
# 7. **Work Environment:**
#    - Investigate 'Department,' 'BusinessTravel,' and 'OverTime' to understand the work environment and its impact on attrition and job satisfaction.
#    - Analyze 'EnvironmentSatisfaction' and 'WorkLifeBalance' in relation to attrition.
#
# 8. **Employee Performance:**
#    - Explore 'PerformanceRating' and its relationship with other variables, such as 'JobInvolvement' and 'TrainingTimesLastYear.'
#
# 9. **Training and Development:**
#    - Analyze 'TrainingTimesLastYear' to assess the investment in employee training and its effects.
#
# 10. **Job Roles and Departments:**
#     - Investigate 'JobRole' and 'Department' to understand the distribution of employees across different roles and departments.
#
# 11. **Tenure and Retention:**
#     - Analyze 'YearsWithCurrManager' to evaluate the impact of manager tenure on attrition.
#     - Assess 'NumCompaniesWorked' to understand employee job history and its relationship with attrition.
#
# 12. **Stock Options:**
#     - Explore 'StockOptionLevel' to understand the distribution of stock options and their impact on employee retention and satisfaction.
#
# 13. **Correlations and Associations:**
#     - Calculate correlations between numeric variables to identify relationships between them.
#
# 14. **Visualization:**
#     - Create various charts and plots (e.g., bar charts, histograms, scatter plots) to visualize the data and relationships between different variables.
#
# 15. **Predictive Modeling:**
#     - Build predictive models to forecast attrition or other outcomes based on the available data, using techniques like logistic regression or decision trees.
#
# 16. **Employee Segmentation:**
#     - Segment employees based on various factors and analyze each segment's characteristics, such as high-performing employees, long-tenured employees, etc.
#
# These are just a few examples of the insights and analyses you can generate with the provided dataset. The specific insights you can obtain will depend on the questions you want to answer and the goals of your analysis.
